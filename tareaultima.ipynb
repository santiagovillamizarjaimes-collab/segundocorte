# %% [markdown]
# <a href="https://colab.research.google.com/github/santiagovillamizarjaimes-collab/segundocorte/blob/main/tareaultima.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0228ef7e-aabb-4877-ade6-aa29b7c6ebb5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0228ef7e-aabb-4877-ade6-aa29b7c6ebb5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
e_capitulos = io.BytesIO(uploaded['e_capitulos.csv'])
e_capitulos = pd.read_csv(e_capitulos, sep = ",", encoding = "latin-1")
e_capitulos.head(4)
# Out:
#    E_01  E_02  E_03  E_04  E_05  E_06  E_07  E_08  E_09  E_10  E_11  E_12  \
# 0     2   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN     2   NaN   NaN
# 1     1  15.0   3.0   2.0   NaN   NaN   NaN   NaN   NaN     2   NaN   NaN
# 2     1  20.0   3.0   1.0   1.0  30.0   1.0   1.0   1.0     2   NaN   NaN
# 3     1  22.0   3.0   2.0   NaN   NaN   NaN   NaN   NaN     2   NaN   NaN
#
#    DIRECTORIO  SECUENCIA_ENCUESTA  SECUENCIA_P  ORDEN
# 0           1                   2            1      2
# 1           2                   1            1      1
# 2           3                   1            1      1
# 3           4                   1            1      1

# %%
tabla_alcohol = pd.DataFrame({
    'edad': e_capitulos['E_02'],
    'fumar': e_capitulos['E_06'],
    'frecuencia diaria': e_capitulos['E_09'],

})
